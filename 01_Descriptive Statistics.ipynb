# %% [markdown]
# # Descriptive Analytics using Pandas

# %%
import pandas as pd
import numpy as np

# %%
d = {'Name':pd.Series(['Tom','James','Ricky','Vin','Steve','Smith','Jack','Lee','David','Gasper','Betina','Andres']),
     'Age':pd.Series([25,26,25,23,30,29,23,34,40,30,51,46]),
     'Rating':pd.Series([4.23,3.24,3.98,2.56,3.20,4.6,3.8,3.78,2.98,4.80,4.10,3.65])}

#Create a DataFrame
df = pd.DataFrame(d)
print(df)
# Out:
#       Name  Age  Rating
# 0      Tom   25    4.23
# 1    James   26    3.24
# 2    Ricky   25    3.98
# 3      Vin   23    2.56
# 4    Steve   30    3.20
# 5    Smith   29    4.60
# 6     Jack   23    3.80
# 7      Lee   34    3.78
# 8    David   40    2.98
# 9   Gasper   30    4.80
# 10  Betina   51    4.10
# 11  Andres   46    3.65

# %%
print(df.mean())
# Out:
# Age       31.833333
# Rating     3.743333
# dtype: float64

# %%
print(df)
print('\n')

print(df.mode())
# Out:
#       Name  Age  Rating
# 0      Tom   25    4.23
# 1    James   26    3.24
# 2    Ricky   25    3.98
# 3      Vin   23    2.56
# 4    Steve   30    3.20
# 5    Smith   29    4.60
# 6     Jack   23    3.80
# 7      Lee   34    3.78
# 8    David   40    2.98
# 9   Gasper   30    4.80
# 10  Betina   51    4.10
# 11  Andres   46    3.65
#
#
#       Name   Age  Rating
# 0   Andres  23.0    2.56
# 1   Betina  25.0    2.98
# 2    David  30.0    3.20
# 3   Gasper   NaN    3.24
# 4     Jack   NaN    3.65
# 5    James   NaN    3.78
# 6      Lee   NaN    3.80
# 7    Ricky   NaN    3.98
# 8    Smith   NaN    4.10
# 9    Steve   NaN    4.23
# 10     Tom   NaN    4.60
# 11     Vin   NaN    4.80

# %%
df.mode(axis=0)
# Out:
#       Name   Age  Rating
# 0   Andres  23.0    2.56
# 1   Betina  25.0    2.98
# 2    David  30.0    3.20
# 3   Gasper   NaN    3.24
# 4     Jack   NaN    3.65
# 5    James   NaN    3.78
# 6      Lee   NaN    3.80
# 7    Ricky   NaN    3.98
# 8    Smith   NaN    4.10
# 9    Steve   NaN    4.23
# 10     Tom   NaN    4.60
# 11     Vin   NaN    4.80

# %%
df.loc[:,"Age"].mode()
# Out:
# 0    23
# 1    25
# 2    30
# dtype: int64

# %%
print(df.min())
# Out:
# Name      Andres
# Age           23
# Rating      2.56
# dtype: object

# %%
print(df.max())
# Out:
# Name      Vin
# Age        51
# Rating    4.8
# dtype: object

# %%
print(df.std())
# Out:
# Age       9.232682
# Rating    0.661628
# dtype: float64

# %%
import matplotlib.pyplot as plt
import numpy as np
import scipy.stats as stats
import math

# %%
mu = 0 # mean
variance = 1 #variance
sigma = math.sqrt(variance)

## bell curve to plot between - 3 sigma till + 3 sigma
x = np.linspace(mu - 3*sigma, mu + 3*sigma, 100)

#plot the curve
plt.plot(x, stats.norm.pdf(x, mu, sigma))
plt.show()

# %%
import pandas as pd

## read a path of file from URL
path = 'http://archive.ics.uci.edu/ml/machine-learning-databases/auto-mpg/auto-mpg.data'

## pass the url and store the data in a variable ans specify the column names
mpg_data = pd.read_csv(path, delim_whitespace=True, header=None,
            names = ['mpg', 'cylinders', 'displacement','horsepower',
            'weight', 'acceleration', 'model_year', 'origin', 'name'],
            na_values='?')
mpg_data
# Out:
#       mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 0    18.0          8         307.0       130.0  3504.0          12.0
# 1    15.0          8         350.0       165.0  3693.0          11.5
# 2    18.0          8         318.0       150.0  3436.0          11.0
# 3    16.0          8         304.0       150.0  3433.0          12.0
# 4    17.0          8         302.0       140.0  3449.0          10.5
# ..    ...        ...           ...         ...     ...           ...
# 393  27.0          4         140.0        86.0  2790.0          15.6
# 394  44.0          4          97.0        52.0  2130.0          24.6
# 395  32.0          4         135.0        84.0  2295.0          11.6
# 396  28.0          4         120.0        79.0  2625.0          18.6
# 397  31.0          4         119.0        82.0  2720.0          19.4
#
#      model_year  origin                       name
# 0            70       1  chevrolet chevelle malibu
# 1            70       1          buick skylark 320
# 2            70       1         plymouth satellite
# 3            70       1              amc rebel sst
# 4            70       1                ford torino
# ..          ...     ...                        ...
# 393          82       1            ford mustang gl
# 394          82       2                  vw pickup
# 395          82       1              dodge rampage
# 396          82       1                ford ranger
# 397          82       1                 chevy s-10
#
# [398 rows x 9 columns]

# %%
mpg_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 398 entries, 0 to 397
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   mpg           398 non-null    float64
#  1   cylinders     398 non-null    int64
#  2   displacement  398 non-null    float64
#  3   horsepower    392 non-null    float64
#  4   weight        398 non-null    float64
#  5   acceleration  398 non-null    float64
#  6   model_year    398 non-null    int64
#  7   origin        398 non-null    int64
#  8   name          398 non-null    object
# dtypes: float64(5), int64(3), object(1)
# memory usage: 28.1+ KB

# %%
mpg_data.describe()
# Out:
#               mpg   cylinders  displacement  horsepower       weight  \
# count  398.000000  398.000000    398.000000  392.000000   398.000000
# mean    23.514573    5.454774    193.425879  104.469388  2970.424623
# std      7.815984    1.701004    104.269838   38.491160   846.841774
# min      9.000000    3.000000     68.000000   46.000000  1613.000000
# 25%     17.500000    4.000000    104.250000   75.000000  2223.750000
# 50%     23.000000    4.000000    148.500000   93.500000  2803.500000
# 75%     29.000000    8.000000    262.000000  126.000000  3608.000000
# max     46.600000    8.000000    455.000000  230.000000  5140.000000
#
#        acceleration  model_year      origin
# count    398.000000  398.000000  398.000000
# mean      15.568090   76.010050    1.572864
# std        2.757689    3.697627    0.802055
# min        8.000000   70.000000    1.000000
# 25%       13.825000   73.000000    1.000000
# 50%       15.500000   76.000000    1.000000
# 75%       17.175000   79.000000    2.000000
# max       24.800000   82.000000    3.000000

# %%
mpg_data.corr()
# Out:
#                    mpg  cylinders  displacement  horsepower    weight  \
# mpg           1.000000  -0.775396     -0.804203   -0.778427 -0.831741
# cylinders    -0.775396   1.000000      0.950721    0.842983  0.896017
# displacement -0.804203   0.950721      1.000000    0.897257  0.932824
# horsepower   -0.778427   0.842983      0.897257    1.000000  0.864538
# weight       -0.831741   0.896017      0.932824    0.864538  1.000000
# acceleration  0.420289  -0.505419     -0.543684   -0.689196 -0.417457
# model_year    0.579267  -0.348746     -0.370164   -0.416361 -0.306564
# origin        0.563450  -0.562543     -0.609409   -0.455171 -0.581024
#
#               acceleration  model_year    origin
# mpg               0.420289    0.579267  0.563450
# cylinders        -0.505419   -0.348746 -0.562543
# displacement     -0.543684   -0.370164 -0.609409
# horsepower       -0.689196   -0.416361 -0.455171
# weight           -0.417457   -0.306564 -0.581024
# acceleration      1.000000    0.288137  0.205873
# model_year        0.288137    1.000000  0.180662
# origin            0.205873    0.180662  1.000000

# %%
mpg_data['mpg'].corr(mpg_data['weight'])
# Out:
# -0.8317409332443352

# %%
mpg_data.drop(['model_year', 'origin'], axis=1).corr(method='spearman')
# Out:
#                    mpg  cylinders  displacement  horsepower    weight  \
# mpg           1.000000  -0.821864     -0.855692   -0.853616 -0.874947
# cylinders    -0.821864   1.000000      0.911876    0.816188  0.873314
# displacement -0.855692   0.911876      1.000000    0.876171  0.945986
# horsepower   -0.853616   0.816188      0.876171    1.000000  0.878819
# weight       -0.874947   0.873314      0.945986    0.878819  1.000000
# acceleration  0.438677  -0.474189     -0.496512   -0.658142 -0.404550
#
#               acceleration
# mpg               0.438677
# cylinders        -0.474189
# displacement     -0.496512
# horsepower       -0.658142
# weight           -0.404550
# acceleration      1.000000

# %%
import matplotlib.pyplot as plt

# %%
mpg_data.drop(['model_year', 'origin'], axis=1).corr(method='pearson').style.format("{:.2}").background_gradient(cmap=plt.get_cmap('coolwarm'), axis=1)
# Out:
# <style  type="text/css" >
# #T_f12af_row0_col0,#T_f12af_row1_col1,#T_f12af_row2_col2,#T_f12af_row3_col3,#T_f12af_row4_col4,#T_f12af_row5_col5{
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }#T_f12af_row0_col1,#T_f12af_row0_col3{
#             background-color:  #4358cb;
#             color:  #f1f1f1;
#         }#T_f12af_row0_col2{
#             background-color:  #3e51c5;
#             color:  #f1f1f1;
#         }#T_f12af_row0_col4,#T_f12af_row1_col0,#T_f12af_row2_col0,#T_f12af_row3_col0,#T_f12af_row4_col0,#T_f12af_row5_col3{
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }#T_f12af_row0_col5{
#             background-color:  #f7b396;
#             color:  #000000;
#         }#T_f12af_row1_col2{
#             background-color:  #be242e;
#             color:  #f1f1f1;
#         }#T_f12af_row1_col3,#T_f12af_row3_col1{
#             background-color:  #d24b40;
#             color:  #f1f1f1;
#         }#T_f12af_row1_col4,#T_f12af_row2_col3,#T_f12af_row3_col2,#T_f12af_row4_col1{
#             background-color:  #c83836;
#             color:  #f1f1f1;
#         }#T_f12af_row1_col5{
#             background-color:  #6a8bef;
#             color:  #000000;
#         }#T_f12af_row2_col1{
#             background-color:  #bd1f2d;
#             color:  #f1f1f1;
#         }#T_f12af_row2_col4,#T_f12af_row4_col2{
#             background-color:  #c12b30;
#             color:  #f1f1f1;
#         }#T_f12af_row2_col5{
#             background-color:  #6788ee;
#             color:  #000000;
#         }#T_f12af_row3_col4{
#             background-color:  #cf453c;
#             color:  #f1f1f1;
#         }#T_f12af_row3_col5{
#             background-color:  #4961d2;
#             color:  #f1f1f1;
#         }#T_f12af_row4_col3{
#             background-color:  #cd423b;
#             color:  #f1f1f1;
#         }#T_f12af_row4_col5{
#             background-color:  #84a7fc;
#             color:  #000000;
#         }#T_f12af_row5_col0{
#             background-color:  #f7ba9f;
#             color:  #000000;
#         }#T_f12af_row5_col1{
#             background-color:  #5b7ae5;
#             color:  #000000;
#         }#T_f12af_row5_col2{
#             background-color:  #5572df;
#             color:  #000000;
#         }#T_f12af_row5_col4{
#             background-color:  #6e90f2;
#             color:  #000000;
#         }</style><table id="T_f12af_" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >mpg</th>        <th class="col_heading level0 col1" >cylinders</th>        <th class="col_heading level0 col2" >displacement</th>        <th class="col_heading level0 col3" >horsepower</th>        <th class="col_heading level0 col4" >weight</th>        <th class="col_heading level0 col5" >acceleration</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_f12af_level0_row0" class="row_heading level0 row0" >mpg</th>
#                         <td id="T_f12af_row0_col0" class="data row0 col0" >1.0</td>
#                         <td id="T_f12af_row0_col1" class="data row0 col1" >-0.78</td>
#                         <td id="T_f12af_row0_col2" class="data row0 col2" >-0.8</td>
#                         <td id="T_f12af_row0_col3" class="data row0 col3" >-0.78</td>
#                         <td id="T_f12af_row0_col4" class="data row0 col4" >-0.83</td>
#                         <td id="T_f12af_row0_col5" class="data row0 col5" >0.42</td>
#             </tr>
#             <tr>
#                         <th id="T_f12af_level0_row1" class="row_heading level0 row1" >cylinders</th>
#                         <td id="T_f12af_row1_col0" class="data row1 col0" >-0.78</td>
#                         <td id="T_f12af_row1_col1" class="data row1 col1" >1.0</td>
#                         <td id="T_f12af_row1_col2" class="data row1 col2" >0.95</td>
#                         <td id="T_f12af_row1_col3" class="data row1 col3" >0.84</td>
#                         <td id="T_f12af_row1_col4" class="data row1 col4" >0.9</td>
#                         <td id="T_f12af_row1_col5" class="data row1 col5" >-0.51</td>
#             </tr>
#             <tr>
#                         <th id="T_f12af_level0_row2" class="row_heading level0 row2" >displacement</th>
#                         <td id="T_f12af_row2_col0" class="data row2 col0" >-0.8</td>
#                         <td id="T_f12af_row2_col1" class="data row2 col1" >0.95</td>
#                         <td id="T_f12af_row2_col2" class="data row2 col2" >1.0</td>
#                         <td id="T_f12af_row2_col3" class="data row2 col3" >0.9</td>
#                         <td id="T_f12af_row2_col4" class="data row2 col4" >0.93</td>
#                         <td id="T_f12af_row2_col5" class="data row2 col5" >-0.54</td>
#             </tr>
#             <tr>
#                         <th id="T_f12af_level0_row3" class="row_heading level0 row3" >horsepower</th>
#                         <td id="T_f12af_row3_col0" class="data row3 col0" >-0.78</td>
#                         <td id="T_f12af_row3_col1" class="data row3 col1" >0.84</td>
#                         <td id="T_f12af_row3_col2" class="data row3 col2" >0.9</td>
#                         <td id="T_f12af_row3_col3" class="data row3 col3" >1.0</td>
#                         <td id="T_f12af_row3_col4" class="data row3 col4" >0.86</td>
#                         <td id="T_f12af_row3_col5" class="data row3 col5" >-0.69</td>
#             </tr>
#             <tr>
#                         <th id="T_f12af_level0_row4" class="row_heading level0 row4" >weight</th>
#                         <td id="T_f12af_row4_col0" class="data row4 col0" >-0.83</td>
#                         <td id="T_f12af_row4_col1" class="data row4 col1" >0.9</td>
#                         <td id="T_f12af_row4_col2" class="data row4 col2" >0.93</td>
#                         <td id="T_f12af_row4_col3" class="data row4 col3" >0.86</td>
#                         <td id="T_f12af_row4_col4" class="data row4 col4" >1.0</td>
#                         <td id="T_f12af_row4_col5" class="data row4 col5" >-0.42</td>
#             </tr>
#             <tr>
#                         <th id="T_f12af_level0_row5" class="row_heading level0 row5" >acceleration</th>
#                         <td id="T_f12af_row5_col0" class="data row5 col0" >0.42</td>
#                         <td id="T_f12af_row5_col1" class="data row5 col1" >-0.51</td>
#                         <td id="T_f12af_row5_col2" class="data row5 col2" >-0.54</td>
#                         <td id="T_f12af_row5_col3" class="data row5 col3" >-0.69</td>
#                         <td id="T_f12af_row5_col4" class="data row5 col4" >-0.42</td>
#                         <td id="T_f12af_row5_col5" class="data row5 col5" >1.0</td>
#             </tr>
#     </tbody></table>

# %%
plt.rcParams['figure.figsize'] = [16, 6]

fig, ax = plt.subplots(nrows=1, ncols=3)

ax=ax.flatten()

cols = ['weight', 'horsepower', 'acceleration']
colors=['#415952', '#f35134', '#243AB5', '#243AB5']
j=0

for i in ax:
    if j==0:
        i.set_ylabel('MPG')
    i.scatter(mpg_data[cols[j]], mpg_data['mpg'],  alpha=0.5, color=colors[j])
    i.set_xlabel(cols[j])
    i.set_title('Pearson: %s'%mpg_data.corr().loc[cols[j]]['mpg'].round(2)+' Spearman: %s'%mpg_data.corr(method='spearman').loc[cols[j]]['mpg'].round(2))
    j+=1

plt.show()

# %%
mpg_data.cov()
# Out:
#                       mpg    cylinders  displacement    horsepower  \
# mpg             61.089611   -10.308911   -655.402318   -233.857926
# cylinders      -10.308911     2.893415    168.623214     55.348244
# displacement  -655.402318   168.623214  10872.199152   3614.033744
# horsepower    -233.857926    55.348244   3614.033744   1481.569393
# weight       -5505.211745  1290.695575  82368.423240  28265.620231
# acceleration     9.058930    -2.370842   -156.332976    -73.186967
# model_year      16.741163    -2.193499   -142.717137    -59.036432
# origin           3.532185    -0.767477    -50.964989    -14.112741
#
#                      weight  acceleration  model_year      origin
# mpg            -5505.211745      9.058930   16.741163    3.532185
# cylinders       1290.695575     -2.370842   -2.193499   -0.767477
# displacement   82368.423240   -156.332976 -142.717137  -50.964989
# horsepower     28265.620231    -73.186967  -59.036432  -14.112741
# weight        717140.990526   -974.899011 -959.946344 -394.639330
# acceleration    -974.899011      7.604848    2.938105    0.455354
# model_year      -959.946344      2.938105   13.672443    0.535790
# origin          -394.639330      0.455354    0.535790    0.643292

# %%
import seaborn as sns

iris = sns.load_dataset('iris')
iris.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
from sklearn.datasets import load_iris

import pandas as pd

# %%
iris = load_iris()
# Load iris into a dataframe and set the field names
df = pd.DataFrame(iris['data'], columns=iris['feature_names'])
df.head()
# Out:
#    sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)
# 0                5.1               3.5                1.4               0.2
# 1                4.9               3.0                1.4               0.2
# 2                4.7               3.2                1.3               0.2
# 3                4.6               3.1                1.5               0.2
# 4                5.0               3.6                1.4               0.2

# %%
df.corr()
# Out:
#                    sepal length (cm)  sepal width (cm)  petal length (cm)  \
# sepal length (cm)           1.000000         -0.117570           0.871754
# sepal width (cm)           -0.117570          1.000000          -0.428440
# petal length (cm)           0.871754         -0.428440           1.000000
# petal width (cm)            0.817941         -0.366126           0.962865
#
#                    petal width (cm)
# sepal length (cm)          0.817941
# sepal width (cm)          -0.366126
# petal length (cm)          0.962865
# petal width (cm)           1.000000

# %%
df.columns
# Out:
# Index(['sepal length (cm)', 'sepal width (cm)', 'petal length (cm)',
#        'petal width (cm)'],
#       dtype='object')

# %%
df['petal length (cm)'].corr(df['sepal length (cm)'])
# Out:
# 0.8717537758865834
